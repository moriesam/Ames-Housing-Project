# %% [markdown]
# ## Creating LASSO Regression Model :<br/>  to predict house sale price

# %% [markdown]
# ### Importing Packages &  Load Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, PowerTransformer
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import r2_score
from sklearn import metrics
import pickle


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
#define the file path to import the cleaned dataset
file_path = '../datasets/train_clean.csv'
train = pd.read_csv(file_path)

# %% [markdown]
# ### Preprocessing & Modeling:

# %% [markdown]
# The following columns are the selected features that will be used in our model:<br>
# - overall_qual
# - gr_live_area
# - garage_area
# - total_bsmt_sf
# - year_remod/add
# - totrms_abvgrd
# - 1st_flr_sf
# - year_built
# - fireplaces
#
# The `saleprice` is target; the column that model will be predicting.
#
# **From preprocessing to building the model:**<br>
#
# **1)** Creating features matrix (X) and target vector (y) - `features matrix`(X) = all  independence variables  and `target vector` (y) = dependant variabvle that model will predict:

# %%
#creating `X` and `y` variables
features = ['overall_qual','gr_liv_area', 'year_remod/add', 'totrms_abvgrd', 
'garage_area',  '1st_flr_sf', 'year_built', 'fireplaces']
X = train[features] # feature matrix
y = np.log(train['saleprice']) # target vector log treansformed to nomalize distribution

# %% [markdown]
# **2)** Instantiate and fitting model:

# %%
l_alphas = np.logspace(-3, 0, 100)
model = LassoCV(alphas=l_alphas, cv=5, max_iter=5000)

# %%
model.fit(X, y)
# Out:
# LassoCV(alphas=array([0.001     , 0.00107227, 0.00114976, 0.00123285, 0.00132194,
#        0.00141747, 0.00151991, 0.00162975, 0.00174753, 0.00187382,
#        0.00200923, 0.00215443, 0.00231013, 0.00247708, 0.00265609,
#        0.00284804, 0.00305386, 0.00327455, 0.00351119, 0.00376494,
#        0.00403702, 0.00432876, 0.00464159, 0.00497702, 0.0053367 ,
#        0.00572237, 0.00613591, 0.00657933, 0.0070548 , 0.00756463,
#        0.008...
#        0.37649358, 0.40370173, 0.43287613, 0.46415888, 0.49770236,
#        0.53366992, 0.57223677, 0.61359073, 0.65793322, 0.70548023,
#        0.75646333, 0.81113083, 0.869749  , 0.93260335, 1.        ]),
#         copy_X=True, cv=5, eps=0.001, fit_intercept=True, max_iter=5000,
#         n_alphas=100, n_jobs=None, normalize=False, positive=False,
#         precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#         verbose=False)

# %%
cross_val_score(model, X, y, cv=5).mean()
# Out:
# 0.8235727608490573

# %% [markdown]
# >**2.1) Feature Engineering:** Before moving forward, checking to see if model score can be optimized through feature engineering - method used :<br>
# - `Interaction Terms` : combination of features matrix (creates an interation of one feature with anoher)
#
# As shown below, model $R^2$ got improved from 0.82 t0 0.85 - thus moving forward with the new featured model:

# %%
#using PolynomialFeatures for interaction terms  
poly = PolynomialFeatures(include_bias=False)
X_poly = poly.fit_transform(X)
poly_model = LassoCV(alphas=l_alphas, cv=5, max_iter=5000)
poly_model.fit(X_poly, y);
cross_val_score(poly_model, X_poly, y, cv=5).mean()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.18168821484989, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.163172117100912, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.14391799182996, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.12414830636545, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.10406950725163, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.083863391374981, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.063905247654763, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.044347802532888, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.025040875866699, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.006104808928148, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.987638305065882, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.969719761304727, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.952409820468095, tolerance: 0.02222427844929789
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.689153725806213, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.560559729657696, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.498832876739614, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.328678721109616, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.125925376081884, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.672867541559217, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.506522639855213, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.328192556767764, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.147512850282492, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.96708797898955, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.788570893416487, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.613371686857342, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.437498272821045, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.078380927922833, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.64583080223732, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.393086818708088, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.020034832326882, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.912170371952183, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.146537544613317, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.342500095528074, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.515844600306117, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.687787891461348, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.86303285154321, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.040334579316209, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.216940583537209, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.390197175739292, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.558030453638164, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.971770812047968, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.618675406497953, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.025724200174208, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.444991824191977, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.87286589413781, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.08446567402374, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.182531284633036, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.274034738873937, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.33433919114131, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.373859701976407, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.40117804442186, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.420844929096532, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.409912362833687, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.319483827636454, tolerance: 0.022333696022067515
#   tol, rng, random, positive)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.16484818360917, tolerance: 0.022333696022067515
#   tol, rng, random, positive)

# %%
#optimal value of alpha
poly_model.alpha_

# %% [markdown]
# **3)** Splitting (X) and (y) into train and test sets:

# %%
X_poly_train, X_poly_test, y_train, y_test = train_test_split(X_poly, y, random_state = 42)

# %% [markdown]
# >**3.1)** Scaling features matrix to standardize the data. This helps to remove the mean and scaling to unit variance for more normal distribution:

# %%
ss = StandardScaler()
ss.fit(X_poly_train)
X_train_sc = ss.transform(X_poly_train)
X_test_sc = ss.transform(X_poly_test)

# %%
# Fit model 
poly_model = poly_model.fit(X_train_sc, y_train)

# %% [markdown]
# Running `coef` and `intercept` to check the bias and coefficnet for each selected feature. in cells below, intercept indicates the average price for a house without any of the selected feature, while  coef indicates the expected price increase per added feature, holding all other variables constant.

# %%
poly_model.intercept_

# %%
poly_model.coef_

# %% [markdown]
# **4)** Get the baseline score for both train/test sets (cross validation) for evaluation:

# %%
#Look into train score
cross_val_score(poly_model, X_train_sc, y_train, cv=5).mean()

# %%
#Look into test score
cross_val_score(poly_model, X_test_sc, y_test, cv=5).mean()

# %% [markdown]
# **5)** Genereting model prediction and finding the line of best fit:

# %%
#model predictions
y_prediction_train = poly_model.predict(X_train_sc)

# %%
#model predictions
y_prediction_test = poly_model.predict(X_test_sc)

# %%
metrics.r2_score(y_train, y_prediction_train)

# %%
# 85% of the variance in the dependant variable can be exlained by this model.
metrics.r2_score(y_test, y_prediction_test)

# %%
residual_test = y_test - y_prediction_test

# %%
residual_train = y_train - y_prediction_train

# %% [markdown]
# Plotting residual to check if variance between our low predictions and our high predictions is considtent, the plot below shows that our target is almost normally distributed. However, it might require normalization for features with extreme outlier:

# %%
plt.hist(residual_test, bins = 20, )
plt.axvline(0, color = 'purple');
plt.savefig('../plots/residual_hist.png')
#plt.title('Residual (sale price  - actual vs predicted)', fontsize = 12);

# %%
sns.regplot(np.exp(y_prediction_test), np.exp(y_test), color='purple')
plt.xlabel(" Predicted sale price")
plt.ylabel("Actual sale price");
#plt.title("Line of Best Fit", fontsize = 12);

# %%
plt.scatter(np.exp(y_prediction_test), residual_test, color = 'purple')
plt.axhline(0, color='b');
plt.xlabel("residual_test")
plt.ylabel("prediction_test")
plt.savefig('../plots/prediction_residual.png')

# %% [markdown]
# **Regression Metrics:**

# %% [markdown]
# **MAE** shows by average our model is 0.11 point off:

# %%
# TRAIN - Mean Absolute Error represents median distance from the predicted value.
metrics.mean_absolute_error(y_train,y_prediction_train)

# %%
#TEST - Mean Absolute Error represents median distance from the predicted value.
metrics.mean_absolute_error(y_test,y_prediction_test)

# %% [markdown]
# **MSE** is the average sum of all errors squared and should be as close to 0 as possible. our model shows a low MSE for both train /test sets. this indicates that the model is fairly fit.

# %%
# TRAIN - Mean Squarred Error represents avg distance squared from the predicted value.
metrics.mean_squared_error(y_train, y_prediction_train)

# %%
#TEST - Mean Squarred Error represents avg distance squared from the predicted value.
metrics.mean_squared_error(y_test, y_prediction_test)

# %% [markdown]
# **RMSE** the goal is always to get RMSE as close to 0 as possible - RMSE indicates that the model is approx off by +/-$27K when predicting the house's sale price.

# %%
#TRAIN - Root Mean Squared Error represents avg distance from the predicted value.
#using np.exp to inverse the log transform for saleprice
np.sqrt(metrics.mean_squared_error(np.exp(y_test), np.exp(y_prediction_test)))

# %%
#TEST- Root Mean Squared Error represents avg distance from the predicted value.
np.sqrt(metrics.mean_squared_error(np.exp(y_train), np.exp(y_prediction_train)))

# %%
# Importing the stats model API
import statsmodels.api as sm
# The Default here is Linear Regression (ordinary least squares regression OLS)
model = sm.OLS(y,X).fit()
model.summary()

# %% [markdown]
# Below cell shows the impact of each feature on property's sale price, for example,  if the house has a fireplace, we expect to see about 8% increase in the sale price.

# %%
np.exp(model.params)

# %% [markdown]
# ### Conclusion and Recommendations:
#
# As of now **`84%`** of variance in the sale price can be explained by this model, indicating that the model is just right. In other words,  model can generalize from train/test data to predict the house value, with **`+/-$29K`** price error. This model is built using numeric datasets, and can be improved by leveraging feature engineerign to include few key features like Neighborhood  by leveraincluding some key features like Neighborgood, style and materials. Nevertheless, this model can be used for the following purposes:<br>
#
# <>**Prediction**<> <br>
# This model can be used for any dataset that includes similar attributes on house features to predict the property's selling price.<br>
#
# <>**Inference**<> <br>
# This model can be used to outline and test some of the most important factors/features that influence house's value.
